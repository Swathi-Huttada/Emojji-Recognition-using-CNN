# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

data = pd.read_csv('/content/drive/My Drive/MiniProject-BDA5/dataset/fer2013.csv')

width, height = 48, 48

datapoints = data['pixels'].tolist()

#getting features for training
X = []
for xseq in datapoints:
    xx = [int(xp) for xp in xseq.split(' ')]
    xx = np.asarray(xx).reshape(width, height)
    X.append(xx.astype('float32'))

X = np.asarray(X)
X = np.expand_dims(X, -1)

#labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
#getting labels for training
y = pd.get_dummies(data['emotion']).values
#columns = pd.get_dummies(data['emotion'])
#y = loc[:, columns].values

#storing them using numpy
np.save('fdataX', X)
np.save('flabels', y)

print("Preprocessing Done")
print("Number of Features: "+str(len(X[0])))
print("Number of Labels: "+ str(len(y[0])))
print("Number of examples in dataset:"+str(len(X)))
print("X,y stored in fdataX.npy and flabels.npy respectively")
# Out:
# Preprocessing Done
# Number of Features: 48
# Number of Labels: 7
# Number of examples in dataset:35887
# X,y stored in fdataX.npy and flabels.npy respectively

# %%
#y[0]
# Out:
# array([1, 0, 0, 0, 0, 0, 0], dtype=uint8)

# %%
#print (datapoints)
print (len(datapoints))
# Out:
# 35887

# %%
import sys, os
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.losses import categorical_crossentropy
from keras.optimizers import Adam
from keras.regularizers import l2

num_features = 64
num_labels = 7
batch_size = 64
epochs = 100
width, height = 48, 48

x = np.load('./fdataX.npy')
y = np.load('./flabels.npy')

x -= np.mean(x, axis=0) 
x /= np.std(x, axis=0)

#for xx in range(10):
#    plt.figure(xx)
#    plt.imshow(x[xx].reshape((48, 48)), interpolation='none', cmap='gray')
#plt.show()

#splitting into training, validation and testing data
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.1, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, random_state=42)

#saving the test samples to be used later
np.save('modXtest', X_test)
np.save('modytest', y_test)

# %%
#Designing the CNN
model = Sequential()

model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', input_shape=(width, height, 1), data_format='channels_last', kernel_regularizer=l2(0.01)))
model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))

#adding this layer to check for more accuracy
model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(Conv2D(2*2*2*num_features, kernel_size=(3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=(2, 2)))
model.add(Dropout(0.5))



model.add(Flatten())

model.add(Dense(2*2*2*num_features, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(2*2*num_features, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(2*num_features, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(num_labels, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 46, 46, 512)       5120
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 46, 46, 512)       2359808
# _________________________________________________________________
# batch_normalization (BatchNo (None, 46, 46, 512)       2048
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 23, 23, 512)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 23, 23, 512)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 23, 23, 512)       2359808
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 23, 23, 512)       2048
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 23, 23, 512)       2359808
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 23, 23, 512)       2048
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 11, 11, 512)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 11, 11, 512)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 512)       2359808
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 11, 11, 512)       2048
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 11, 11, 512)       2359808
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 11, 11, 512)       2048
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 512)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 5, 5, 512)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 5, 5, 512)         2359808
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 5, 5, 512)         2048
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 512)         2359808
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 2, 2, 512)         2048
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 2, 2, 512)         2359808
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 2, 2, 512)         2048
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 512)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 21,689,607
# Trainable params: 21,680,391
# Non-trainable params: 9,216
# _________________________________________________________________

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Compliling the model with adam optimiser and categorical crossentropy loss
model.compile(loss=categorical_crossentropy,
              optimizer=Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-7),
              metrics=['accuracy'])

#training the model
model.fit(np.array(X_train), np.array(y_train),
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(np.array(X_valid), np.array(y_valid)),
          shuffle=True)

#saving the  model to be used later
fer_json = model.to_json()
with open("fer2.json", "w") as json_file:
    json_file.write(fer_json)
model.save_weights("fer2.h5")
print("Saved model to disk")
# Out:
# Epoch 1/100
# 455/455 [==============================] - 90s 177ms/step - loss: 2.1774 - accuracy: 0.2084 - val_loss: 1.8129 - val_accuracy: 0.2594
# Epoch 2/100
# 455/455 [==============================] - 79s 175ms/step - loss: 1.8406 - accuracy: 0.2451 - val_loss: 1.7842 - val_accuracy: 0.2628
# Epoch 3/100
# 455/455 [==============================] - 79s 175ms/step - loss: 1.8079 - accuracy: 0.2530 - val_loss: 1.6977 - val_accuracy: 0.3173
# Epoch 4/100
# 455/455 [==============================] - 79s 175ms/step - loss: 1.6950 - accuracy: 0.3187 - val_loss: 1.5040 - val_accuracy: 0.4071
# Epoch 5/100
# 455/455 [==============================] - 79s 174ms/step - loss: 1.5586 - accuracy: 0.3836 - val_loss: 1.4089 - val_accuracy: 0.4334
# Epoch 6/100
# 455/455 [==============================] - 79s 174ms/step - loss: 1.4687 - accuracy: 0.4237 - val_loss: 1.3575 - val_accuracy: 0.4635
# Epoch 7/100
# 455/455 [==============================] - 79s 174ms/step - loss: 1.4078 - accuracy: 0.4383 - val_loss: 1.4758 - val_accuracy: 0.4276
# Epoch 8/100
# 455/455 [==============================] - 79s 174ms/step - loss: 1.3717 - accuracy: 0.4559 - val_loss: 1.3935 - val_accuracy: 0.4359
# Epoch 9/100
# 455/455 [==============================] - 79s 174ms/step - loss: 1.3576 - accuracy: 0.4569 - val_loss: 1.3806 - val_accuracy: 0.4833
# Epoch 10/100
# 455/455 [==============================] - 79s 174ms/step - loss: 1.3079 - accuracy: 0.4967 - val_loss: 1.2555 - val_accuracy: 0.5307
# Epoch 11/100
# 455/455 [==============================] - 79s 174ms/step - loss: 1.2740 - accuracy: 0.5210 - val_loss: 1.2222 - val_accuracy: 0.5257
# Epoch 12/100
# 455/455 [==============================] - 79s 174ms/step - loss: 1.2413 - accuracy: 0.5385 - val_loss: 1.1856 - val_accuracy: 0.5616
# Epoch 13/100
# 455/455 [==============================] - 79s 174ms/step - loss: 1.1877 - accuracy: 0.5604 - val_loss: 1.1909 - val_accuracy: 0.5554
# Epoch 14/100
# 455/455 [==============================] - 79s 174ms/step - loss: 1.1407 - accuracy: 0.5826 - val_loss: 1.1389 - val_accuracy: 0.5786
# Epoch 15/100
# 455/455 [==============================] - 79s 175ms/step - loss: 1.1157 - accuracy: 0.5987 - val_loss: 1.1304 - val_accuracy: 0.5882
# Epoch 16/100
# 455/455 [==============================] - 79s 174ms/step - loss: 1.0835 - accuracy: 0.6095 - val_loss: 1.1319 - val_accuracy: 0.5830
# Epoch 17/100
# 455/455 [==============================] - 79s 175ms/step - loss: 1.0527 - accuracy: 0.6232 - val_loss: 1.1111 - val_accuracy: 0.5950
# Epoch 18/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.9980 - accuracy: 0.6452 - val_loss: 1.0861 - val_accuracy: 0.6059
# Epoch 19/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.9515 - accuracy: 0.6645 - val_loss: 1.0864 - val_accuracy: 0.6068
# Epoch 20/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.9157 - accuracy: 0.6790 - val_loss: 1.0846 - val_accuracy: 0.6260
# Epoch 21/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.8603 - accuracy: 0.6998 - val_loss: 1.1433 - val_accuracy: 0.6050
# Epoch 22/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.8198 - accuracy: 0.7134 - val_loss: 1.0477 - val_accuracy: 0.6359
# Epoch 23/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.7880 - accuracy: 0.7329 - val_loss: 1.0545 - val_accuracy: 0.6350
# Epoch 24/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.7293 - accuracy: 0.7462 - val_loss: 1.0837 - val_accuracy: 0.6372
# Epoch 25/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.7062 - accuracy: 0.7564 - val_loss: 1.1026 - val_accuracy: 0.6399
# Epoch 26/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.6751 - accuracy: 0.7740 - val_loss: 1.1679 - val_accuracy: 0.6567
# Epoch 27/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.6292 - accuracy: 0.7881 - val_loss: 1.1543 - val_accuracy: 0.6399
# Epoch 28/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.5962 - accuracy: 0.8002 - val_loss: 1.1433 - val_accuracy: 0.6520
# Epoch 29/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.5622 - accuracy: 0.8099 - val_loss: 1.2227 - val_accuracy: 0.6554
# Epoch 30/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.5565 - accuracy: 0.8172 - val_loss: 1.2000 - val_accuracy: 0.6533
# Epoch 31/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.5042 - accuracy: 0.8356 - val_loss: 1.1859 - val_accuracy: 0.6675
# Epoch 32/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.4868 - accuracy: 0.8421 - val_loss: 1.2989 - val_accuracy: 0.6536
# Epoch 33/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.5178 - accuracy: 0.8328 - val_loss: 1.2661 - val_accuracy: 0.6653
# Epoch 34/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.4359 - accuracy: 0.8627 - val_loss: 1.2170 - val_accuracy: 0.6567
# Epoch 35/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.4118 - accuracy: 0.8675 - val_loss: 1.2309 - val_accuracy: 0.6635
# Epoch 36/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.3779 - accuracy: 0.8789 - val_loss: 1.3321 - val_accuracy: 0.6619
# Epoch 37/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.3742 - accuracy: 0.8820 - val_loss: 1.3592 - val_accuracy: 0.6632
# Epoch 38/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.3597 - accuracy: 0.8860 - val_loss: 1.3581 - val_accuracy: 0.6647
# Epoch 39/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.3591 - accuracy: 0.8883 - val_loss: 1.3925 - val_accuracy: 0.6706
# Epoch 40/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.3368 - accuracy: 0.8965 - val_loss: 1.3974 - val_accuracy: 0.6622
# Epoch 41/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.3176 - accuracy: 0.9024 - val_loss: 1.4105 - val_accuracy: 0.6687
# Epoch 42/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.3009 - accuracy: 0.9095 - val_loss: 1.4402 - val_accuracy: 0.6755
# Epoch 43/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.3027 - accuracy: 0.9087 - val_loss: 1.5725 - val_accuracy: 0.6678
# Epoch 44/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.3207 - accuracy: 0.9033 - val_loss: 1.4341 - val_accuracy: 0.6709
# Epoch 45/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.2717 - accuracy: 0.9176 - val_loss: 1.4737 - val_accuracy: 0.6728
# Epoch 46/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.2529 - accuracy: 0.9248 - val_loss: 1.4923 - val_accuracy: 0.6743
# Epoch 47/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.2619 - accuracy: 0.9197 - val_loss: 1.7117 - val_accuracy: 0.6526
# Epoch 48/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.3002 - accuracy: 0.9132 - val_loss: 1.4148 - val_accuracy: 0.6635
# Epoch 49/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.2408 - accuracy: 0.9254 - val_loss: 1.8056 - val_accuracy: 0.6641
# Epoch 50/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.2252 - accuracy: 0.9348 - val_loss: 1.5216 - val_accuracy: 0.6678
# Epoch 51/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.2232 - accuracy: 0.9334 - val_loss: 1.5729 - val_accuracy: 0.6681
# Epoch 52/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.2152 - accuracy: 0.9379 - val_loss: 1.6564 - val_accuracy: 0.6700
# Epoch 53/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.2219 - accuracy: 0.9345 - val_loss: 1.7300 - val_accuracy: 0.6669
# Epoch 54/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.2078 - accuracy: 0.9366 - val_loss: 1.9783 - val_accuracy: 0.6715
# Epoch 55/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.2133 - accuracy: 0.9356 - val_loss: 1.6907 - val_accuracy: 0.6669
# Epoch 56/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1964 - accuracy: 0.9401 - val_loss: 1.8413 - val_accuracy: 0.6669
# Epoch 57/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.2040 - accuracy: 0.9417 - val_loss: 1.7044 - val_accuracy: 0.6678
# Epoch 58/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.2046 - accuracy: 0.9391 - val_loss: 1.8238 - val_accuracy: 0.6656
# Epoch 59/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1893 - accuracy: 0.9445 - val_loss: 1.9463 - val_accuracy: 0.6749
# Epoch 60/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1709 - accuracy: 0.9492 - val_loss: 1.7834 - val_accuracy: 0.6653
# Epoch 61/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1657 - accuracy: 0.9504 - val_loss: 1.6486 - val_accuracy: 0.6585
# Epoch 62/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1781 - accuracy: 0.9486 - val_loss: 1.8587 - val_accuracy: 0.6721
# Epoch 63/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1760 - accuracy: 0.9497 - val_loss: 1.7667 - val_accuracy: 0.6656
# Epoch 64/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1798 - accuracy: 0.9454 - val_loss: 1.7968 - val_accuracy: 0.6697
# Epoch 65/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.2295 - accuracy: 0.9327 - val_loss: 1.9426 - val_accuracy: 0.6731
# Epoch 66/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1687 - accuracy: 0.9540 - val_loss: 1.8012 - val_accuracy: 0.6672
# Epoch 67/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1535 - accuracy: 0.9559 - val_loss: 2.0482 - val_accuracy: 0.6666
# Epoch 68/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1581 - accuracy: 0.9541 - val_loss: 1.9764 - val_accuracy: 0.6706
# Epoch 69/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1597 - accuracy: 0.9526 - val_loss: 2.0132 - val_accuracy: 0.6684
# Epoch 70/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1487 - accuracy: 0.9563 - val_loss: 2.2000 - val_accuracy: 0.6675
# Epoch 71/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1524 - accuracy: 0.9569 - val_loss: 1.9577 - val_accuracy: 0.6709
# Epoch 72/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1440 - accuracy: 0.9594 - val_loss: 2.0939 - val_accuracy: 0.6746
# Epoch 73/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1396 - accuracy: 0.9596 - val_loss: 1.7785 - val_accuracy: 0.6650
# Epoch 74/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.1409 - accuracy: 0.9589 - val_loss: 1.9965 - val_accuracy: 0.6752
# Epoch 75/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.1336 - accuracy: 0.9617 - val_loss: 1.9000 - val_accuracy: 0.6706
# Epoch 76/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.1406 - accuracy: 0.9607 - val_loss: 2.3350 - val_accuracy: 0.6675
# Epoch 77/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.1418 - accuracy: 0.9599 - val_loss: 1.7644 - val_accuracy: 0.6551
# Epoch 78/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.1491 - accuracy: 0.9585 - val_loss: 1.8663 - val_accuracy: 0.6607
# Epoch 79/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.1421 - accuracy: 0.9588 - val_loss: 2.1250 - val_accuracy: 0.6681
# Epoch 80/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.1365 - accuracy: 0.9612 - val_loss: 1.8813 - val_accuracy: 0.6644
# Epoch 81/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.1355 - accuracy: 0.9616 - val_loss: 2.0167 - val_accuracy: 0.6740
# Epoch 82/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1257 - accuracy: 0.9636 - val_loss: 2.0945 - val_accuracy: 0.6706
# Epoch 83/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1400 - accuracy: 0.9608 - val_loss: 1.9325 - val_accuracy: 0.6644
# Epoch 84/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.1244 - accuracy: 0.9641 - val_loss: 2.0068 - val_accuracy: 0.6659
# Epoch 85/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.1249 - accuracy: 0.9654 - val_loss: 1.9869 - val_accuracy: 0.6693
# Epoch 86/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.1277 - accuracy: 0.9650 - val_loss: 2.3594 - val_accuracy: 0.6715
# Epoch 87/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.1334 - accuracy: 0.9627 - val_loss: 1.9723 - val_accuracy: 0.6619
# Epoch 88/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.1376 - accuracy: 0.9633 - val_loss: 1.8191 - val_accuracy: 0.6663
# Epoch 89/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.1220 - accuracy: 0.9662 - val_loss: 2.0196 - val_accuracy: 0.6681
# Epoch 90/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1240 - accuracy: 0.9669 - val_loss: 1.9619 - val_accuracy: 0.6728
# Epoch 91/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1169 - accuracy: 0.9652 - val_loss: 2.2783 - val_accuracy: 0.6659
# Epoch 92/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1098 - accuracy: 0.9704 - val_loss: 1.9248 - val_accuracy: 0.6669
# Epoch 93/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.1029 - accuracy: 0.9718 - val_loss: 2.0351 - val_accuracy: 0.6598
# Epoch 94/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.1142 - accuracy: 0.9683 - val_loss: 2.2203 - val_accuracy: 0.6647
# Epoch 95/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1088 - accuracy: 0.9685 - val_loss: 2.2131 - val_accuracy: 0.6647
# Epoch 96/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1177 - accuracy: 0.9677 - val_loss: 2.1426 - val_accuracy: 0.6644
# Epoch 97/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1086 - accuracy: 0.9699 - val_loss: 2.4577 - val_accuracy: 0.6594
# Epoch 98/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1468 - accuracy: 0.9591 - val_loss: 2.4910 - val_accuracy: 0.6681
# Epoch 99/100
# 455/455 [==============================] - 79s 174ms/step - loss: 0.1055 - accuracy: 0.9720 - val_loss: 2.2758 - val_accuracy: 0.6663
# Epoch 100/100
# 455/455 [==============================] - 79s 173ms/step - loss: 0.1035 - accuracy: 0.9719 - val_loss: 2.5784 - val_accuracy: 0.6678
# Saved model to disk

# %%
# load json and create model
from __future__ import division
from keras.models import Sequential
from keras.layers import Dense
from keras.models import model_from_json
import os
import numpy as np

json_file = open('fer.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)

# Load weights into new model

loaded_model.load_weights("fer.h5")
print("Loaded model from disk")

truey=[]
predy=[]
x = np.load('./modXtest.npy')
y = np.load('./modytest.npy')

yhat= loaded_model.predict(x)
yh = yhat.tolist() #predicted
yt = y.tolist()    #ytest
count = 0

for i in range(len(y)):
    yy = max(yh[i])  
    yyt = max(yt[i])
    predy.append(yh[i].index(yy))
    truey.append(yt[i].index(yyt))
    if(yh[i].index(yy)== yt[i].index(yyt)):#pred==true
        count+=1

acc = (count/len(y))*100

#saving values for confusion matrix and analysis
np.save('truey', truey)
np.save('predy', predy)
print("Predicted and true label values saved")
print("Accuracy on test set :"+str(acc)+"%")
# Out:
# Loaded model from disk
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f2240003d08> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Predicted and true label values saved
# Accuracy on test set :66.36946224575091%

# %%
#yh[i].index(yy) #3
#max(yh[i]) #1.0
#max(yt[i]) #1
len(yh)
# Out:
# 3589

# %% [markdown]
# **CONFUSION MATRIX**

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

y_true = np.load('./truey.npy')
y_pred = np.load('./predy.npy')
cm = confusion_matrix(y_true, y_pred)
labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']
title='Confusion matrix'
print(cm)

plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title(title)
plt.colorbar()
tick_marks = np.arange(len(labels))
plt.xticks(tick_marks, labels, rotation=45)
plt.yticks(tick_marks, labels)
fmt = 'd'
thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, format(cm[i, j], fmt),
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.tight_layout()
plt.show()
# Out:
# [[291   6  49  22  72   9  49]
#  [ 11  33   3   2   2   1   0]
#  [ 47   7 283  21  95  45  47]
#  [ 22   0  18 751  30  14  46]
#  [ 59   1  69  29 346   1  83]
#  [ 11   0  54  31   4 301  13]
#  [ 39   1  37  51  95  11 377]]

# %% [markdown]
# ## **CUSTOM TEST**

# %%
# load json and create model
from __future__ import division
from keras.models import Sequential
from keras.layers import Dense
from keras.models import model_from_json
import numpy
import os
import numpy as np
import cv2
from google.colab.patches import cv2_imshow


#loading the model
json_file = open('fer.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("fer.h5")
print("Loaded model from disk")

#setting image resizing parameters
WIDTH = 48
HEIGHT = 48
x=None
y=None
labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

#loading image
#path = r 'C:\Users\r077TX\Pictures\Screenshots\CNN\download.jpg'
full_size_image = cv2.imread("h2.jpg")
print("Image Loaded")
gray=cv2.cvtColor(full_size_image,cv2.COLOR_RGB2GRAY)
face = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
faces = face.detectMultiScale(gray,1.3,10)

#detecting faces
for (x, y, w, h) in faces:
        roi_gray = gray[y:y + h, x:x + w]
        cropped_img = np.expand_dims(np.expand_dims(cv2.resize(roi_gray, (48, 48)), -1), 0)
        cv2.normalize(cropped_img, cropped_img, alpha=0, beta=1, norm_type=cv2.NORM_L2, dtype=cv2.CV_32F)
        cv2.rectangle(full_size_image, (x, y), (x + w, y + h), (0, 255, 0), 1)
        #predicting the emotion
        yhat= loaded_model.predict(cropped_img)
        cv2.putText(full_size_image, labels[int(np.argmax(yhat))], (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 1, cv2.LINE_AA)
        print("Emotion: "+labels[int(np.argmax(yhat))])

cv2_imshow(full_size_image)
cv2.waitKey()
# Out:
# Loaded model from disk
# Image Loaded
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f22241dd378> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Emotion: Happy
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F2243E439E8>
# -1

# %%
# load json and create model
from __future__ import division
from keras.models import Sequential
from keras.layers import Dense
from keras.models import model_from_json
import numpy
import os
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

#loading the model
json_file = open('fer.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("fer.h5")
print("Loaded model from disk")

#setting image resizing parameters
WIDTH = 48
HEIGHT = 48
x=None
y=None
labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Sad', 'Surprise', 'Neutral']

#loading image
#path = r 'C:\Users\r077TX\Pictures\Screenshots\CNN\download.jpg'
full_size_image = cv2.imread("a1.jpg")
print("Image Loaded")
gray=cv2.cvtColor(full_size_image,cv2.COLOR_RGB2GRAY)
face = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
faces = face.detectMultiScale(gray,1.3,10)

#detecting faces
for (x, y, w, h) in faces:
        roi_gray = gray[y:y + h, x:x + w]
        cropped_img = np.expand_dims(np.expand_dims(cv2.resize(roi_gray, (48, 48)), -1), 0)
        cv2.normalize(cropped_img, cropped_img, alpha=0, beta=1, norm_type=cv2.NORM_L2, dtype=cv2.CV_32F)
        cv2.rectangle(full_size_image, (x, y), (x + w, y + h), (0, 255, 0), 1)
        #predicting the emotion
        yhat= loaded_model.predict(cropped_img)
        cv2.putText(full_size_image, labels[int(np.argmax(yhat))], (x, y), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 1, cv2.LINE_AA)
        print("Emotion: "+labels[int(np.argmax(yhat))])

cv2_imshow(full_size_image)
cv2.waitKey()
# Out:
# Loaded model from disk
# Image Loaded
# WARNING:tensorflow:11 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f20dfc72488> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Emotion: Fear
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F2100189BE0>
# -1
